# %% [markdown]
# ###### Project: Adverse Medical Outcomes Prediction
# ##### Data Scientist: Victoria M. Ng

# %% [markdown]
# # Import libraries

# %%
# General system libraries
import os
import sys
from IPython.display import Image, Markdown
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# Dataframe libraries
import pandas as pd
from pandas import DataFrame, read_csv

# Number manipulation
import scipy.sparse
from scipy.ndimage.filters import generic_filter
import patsy
import numpy as np

# Plotting libaries
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# Data type libaries
from datetime import datetime as dt

# File manipulation
import pickle
import pandas.io.sql as pd_sql
import psycopg2 as pg

# NLP libraries
import wikipedia as wiki
from nltk import word_tokenize, sent_tokenize,FreqDist
from nltk.corpus import stopwords
import gensim as gn
from gensim import corpora, models, similarities
from collections import defaultdict
from six import iteritems
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from spacy.lang.en.stop_words import STOP_WORDS

# Scraping libraries
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
chromedriver = "/home/victoria/projects/metis/Project3/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# Stats libaries
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import datasets, linear_model, metrics
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import svm, datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier


# Other libaries
import geopy
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 2018-05-11 15:36:36,981 : INFO : 'pattern' package not found; tag filters are not available for English
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Create a list of stop words

# %%
stop_words = list(STOP_WORDS)
stop_words.append('a')
stop_words
# Out:
# ['in',
#  'almost',
#  'onto',
#  'neither',
#  'three',
#  'so',
#  'yet',
#  'go',
#  'hundred',
#  'would',
#  'fifteen',
#  'some',
#  'using',
#  'because',
#  'whereas',
#  'nothing',
#  'on',
#  'too',
#  'well',
#  'toward',
#  'who',
#  'still',
#  'everything',
#  'last',
#  'same',
#  'much',
#  'make',
#  'meanwhile',
#  'fifty',
#  'only',
#  'see',
#  'whither',
#  'wherein',
#  'third',
#  'nobody',
#  'several',
#  'no',
#  'ours',
#  'else',
#  'say',
#  'done',
#  'quite',
#  'someone',
#  'become',
#  'her',
#  'that',
#  'them',
#  'whereby',
#  'their',
#  'during',
#  'him',
#  'becoming',
#  'back',
#  'next',
#  'eight',
#  'nine',
#  'yours',
#  'off',
#  'been',
#  'we',
#  'has',
#  'every',
#  'unless',
#  'themselves',
#  'us',
#  'me',
#  'somehow',
#  'there',
#  'everywhere',
#  'regarding',
#  'per',
#  'before',
#  'whom',
#  'how',
#  'further',
#  'sixty',
#  'then',
#  'which',
#  'less',
#  'elsewhere',
#  'became',
#  'latterly',
#  'many',
#  'sometime',
#  'whether',
#  'anyone',
#  'an',
#  'due',
#  'just',
#  'but',
#  'must',
#  'thus',
#  'wherever',
#  'whole',
#  'such',
#  'thereafter',
#  'a',
#  'four',
#  'moreover',
#  'where',
#  'already',
#  'is',
#  'top',
#  'without',
#  'ever',
#  'she',
#  'more',
#  'none',
#  'part',
#  'other',
#  'twelve',
#  'mine',
#  'each',
#  'put',
#  'either',
#  'thereby',
#  'eleven',
#  'below',
#  'whenever',
#  'show',
#  'through',
#  'and',
#  'upon',
#  'here',
#  'thereupon',
#  'otherwise',
#  'also',
#  'get',
#  'when',
#  'whose',
#  'alone',
#  'although',
#  'being',
#  'did',
#  'any',
#  'under',
#  'anything',
#  'former',
#  'another',
#  'they',
#  'be',
#  'anyhow',
#  'from',
#  'its',
#  'amongst',
#  'by',
#  'cannot',
#  'however',
#  'nor',
#  'not',
#  'hereby',
#  'am',
#  'once',
#  'please',
#  'take',
#  'six',
#  'whatever',
#  'had',
#  'now',
#  'hereafter',
#  'while',
#  'becomes',
#  'itself',
#  'therein',
#  'could',
#  'have',
#  'latter',
#  'what',
#  'somewhere',
#  'do',
#  'himself',
#  'others',
#  'both',
#  're',
#  'though',
#  'at',
#  'namely',
#  'nowhere',
#  'since',
#  'was',
#  'across',
#  'nevertheless',
#  'few',
#  'hers',
#  'beside',
#  'enough',
#  'might',
#  'with',
#  'rather',
#  'therefore',
#  'than',
#  'of',
#  'about',
#  'the',
#  'up',
#  'our',
#  'used',
#  'were',
#  'may',
#  'never',
#  'towards',
#  'my',
#  'among',
#  'myself',
#  'anywhere',
#  'move',
#  'serious',
#  'can',
#  'mostly',
#  'hereupon',
#  'those',
#  'doing',
#  'yourselves',
#  'until',
#  'always',
#  'above',
#  'again',
#  'down',
#  'if',
#  'keep',
#  'something',
#  'sometimes',
#  'together',
#  'twenty',
#  'you',
#  'over',
#  'within',
#  'whoever',
#  'amount',
#  'why',
#  'into',
#  'one',
#  'to',
#  'ourselves',
#  'two',
#  'full',
#  'formerly',
#  'herein',
#  'via',
#  'five',
#  'he',
#  'hence',
#  'seemed',
#  'ca',
#  'besides',
#  'various',
#  'or',
#  'very',
#  'everyone',
#  'side',
#  'ten',
#  'perhaps',
#  'seem',
#  'this',
#  'give',
#  'beforehand',
#  'thence',
#  'thru',
#  'whereupon',
#  'along',
#  'after',
#  'against',
#  'even',
#  'will',
#  'name',
#  'bottom',
#  'i',
#  'really',
#  'throughout',
#  'it',
#  'seems',
#  'his',
#  'these',
#  'indeed',
#  'as',
#  'afterwards',
#  'for',
#  'noone',
#  'should',
#  'own',
#  'whence',
#  'anyway',
#  'all',
#  'front',
#  'most',
#  'seeming',
#  'out',
#  'call',
#  'herself',
#  'yourself',
#  'whereafter',
#  'beyond',
#  'made',
#  'are',
#  'first',
#  'except',
#  'behind',
#  'around',
#  'least',
#  'often',
#  'forty',
#  'between',
#  'empty',
#  'your',
#  'does',
#  'a']

# %% [markdown]
# # Define a function to make each wiki page one long string

# %%
from string import punctuation

for char in punctuation:
    print(char)
# Out:
# !
# "
# #
# $
# %
# &
# '
# (
# )
# *
# +
# ,
# -
# .
# /
# :
# ;
# <
# =
# >
# ?
# @
# [
# \
# ]
# ^
# _
# `
# {
# |
# }
# ~

# %%
def clean_page(page_list):
    clean_list = []
    clean_page = []
    for string in page_list: 
        string=string.lower()
        for char in punctuation:
            string = string.replace(char,'')
        string=string.replace('0','')
        string=string.replace('1','')
        string=string.replace('2','')
        string=string.replace('3','')
        string=string.replace('4','')
        string=string.replace('5','')
        string=string.replace('6','')
        string=string.replace('7','')
        string=string.replace('8','')
        string=string.replace('9','')
        clean_list.append(string)
    clean_page = ''.join(clean_list)
    return clean_page

# %% [markdown]
# # Import the food_df symptoms list and dict

# %% [markdown]
# Remember to maintain the order of the dict since you're making a list out of the keys and iterating on that list

# %%
with open('unique_food_df_symptoms_list.pkl', 'rb') as picklefile: 
    unique_food_df_symptoms_list = pickle.load(picklefile)

# %%
len(unique_food_df_symptoms_list)
# Out:
# 3004

# %%
with open('symptoms_food_df_dict.pkl', 'rb') as picklefile: 
    symptoms_food_df_dict = pickle.load(picklefile)

# %%
symptoms_food_df_dict['diarrhoea']
# Out:
# 852

# %%
list_of_instance_counts = list(symptoms_food_df_dict.values())
list_of_instance_counts
# Out:
# [2660,
#  2336,
#  2983,
#  757,
#  1430,
#  923,
#  643,
#  707,
#  2637,
#  798,
#  1826,
#  620,
#  1343,
#  874,
#  441,
#  2087,
#  2109,
#  2179,
#  2056,
#  638,
#  1047,
#  2917,
#  92,
#  209,
#  835,
#  1460,
#  1336,
#  1506,
#  1888,
#  1143,
#  1024,
#  2075,
#  2677,
#  1156,
#  1753,
#  763,
#  1614,
#  12,
#  2963,
#  852,
#  1018,
#  916,
#  1061,
#  2594,
#  2703,
#  2937,
#  2531,
#  973,
#  1064,
#  1058,
#  538,
#  1915,
#  14,
#  903,
#  2701,
#  2537,
#  2538,
#  327,
#  540,
#  2449,
#  2110,
#  1523,
#  221,
#  1667,
#  822,
#  1864,
#  1116,
#  2670,
#  603,
#  1710,
#  1137,
#  432,
#  1109,
#  2866,
#  2633,
#  18,
#  351,
#  1442,
#  821,
#  449,
#  176,
#  2777,
#  1493,
#  1279,
#  1065,
#  1063,
#  2486,
#  1067,
#  167,
#  2694,
#  1448,
#  492,
#  125,
#  1817,
#  1773,
#  652,
#  1616,
#  217,
#  81,
#  2343,
#  2285,
#  2659,
#  66,
#  2097,
#  1837,
#  133,
#  1879,
#  855,
#  866,
#  2339,
#  823,
#  2436,
#  706,
#  1861,
#  1104,
#  2992,
#  1894,
#  373,
#  1121,
#  869,
#  2218,
#  2114,
#  800,
#  1564,
#  2695,
#  2421,
#  2976,
#  740,
#  1184,
#  1274,
#  1432,
#  1954,
#  2873,
#  2872,
#  1290,
#  625,
#  2241,
#  2807,
#  1838,
#  479,
#  2102,
#  76,
#  920,
#  2123,
#  2455,
#  1507,
#  898,
#  2086,
#  2404,
#  1235,
#  252,
#  2686,
#  2269,
#  1527,
#  1301,
#  780,
#  150,
#  778,
#  2323,
#  721,
#  953,
#  2077,
#  637,
#  2940,
#  495,
#  197,
#  2661,
#  1696,
#  2663,
#  1844,
#  917,
#  1296,
#  1468,
#  2979,
#  1873,
#  715,
#  358,
#  461,
#  2987,
#  2065,
#  871,
#  2544,
#  2964,
#  1082,
#  1711,
#  2002,
#  10,
#  1399,
#  1567,
#  1593,
#  1341,
#  573,
#  574,
#  1987,
#  2527,
#  2440,
#  1051,
#  169,
#  1836,
#  1056,
#  2359,
#  1258,
#  2022,
#  1595,
#  859,
#  1368,
#  140,
#  1695,
#  1988,
#  1356,
#  1650,
#  907,
#  2658,
#  832,
#  5,
#  436,
#  912,
#  199,
#  2315,
#  595,
#  248,
#  2655,
#  876,
#  489,
#  1939,
#  1481,
#  2779,
#  1392,
#  634,
#  229,
#  1902,
#  1903,
#  398,
#  1546,
#  2558,
#  591,
#  897,
#  1321,
#  1119,
#  809,
#  860,
#  2516,
#  569,
#  374,
#  1210,
#  1802,
#  1122,
#  1209,
#  395,
#  135,
#  1304,
#  1212,
#  844,
#  1760,
#  2103,
#  168,
#  2923,
#  807,
#  1213,
#  380,
#  1129,
#  1917,
#  2302,
#  2786,
#  734,
#  2727,
#  1484,
#  2533,
#  2338,
#  1479,
#  688,
#  598,
#  2973,
#  29,
#  1700,
#  661,
#  1615,
#  1413,
#  1734,
#  2565,
#  2341,
#  2579,
#  1462,
#  1609,
#  260,
#  98,
#  1463,
#  1651,
#  651,
#  989,
#  1549,
#  905,
#  1610,
#  1099,
#  1371,
#  2654,
#  1703,
#  1374,
#  299,
#  833,
#  1936,
#  1232,
#  2991,
#  975,
#  1035,
#  1311,
#  378,
#  424,
#  515,
#  1464,
#  1552,
#  504,
#  4,
#  631,
#  1449,
#  343,
#  1198,
#  1344,
#  1473,
#  1096,
#  1176,
#  1320,
#  1584,
#  1105,
#  2559,
#  1236,
#  51,
#  2722,
#  674,
#  750,
#  753,
#  993,
#  126,
#  1379,
#  335,
#  980,
#  1390,
#  1237,
#  1286,
#  1102,
#  1516,
#  805,
#  1295,
#  2101,
#  1783,
#  628,
#  727,
#  74,
#  1984,
#  2390,
#  1010,
#  1009,
#  1073,
#  2546,
#  862,
#  1161,
#  124,
#  1937,
#  1103,
#  225,
#  718,
#  1644,
#  274,
#  2106,
#  984,
#  985,
#  1787,
#  2573,
#  223,
#  2205,
#  2543,
#  1812,
#  1097,
#  1200,
#  1633,
#  1382,
#  2383,
#  2098,
#  2301,
#  731,
#  2419,
#  1907,
#  996,
#  2475,
#  853,
#  2764,
#  555,
#  1798,
#  1900,
#  2145,
#  2601,
#  47,
#  1466,
#  2916,
#  2749,
#  2885,
#  1020,
#  654,
#  2566,
#  2571,
#  2629,
#  1692,
#  1324,
#  1871,
#  2474,
#  1941,
#  1188,
#  455,
#  494,
#  2,
#  2411,
#  2381,
#  1083,
#  1501,
#  1342,
#  433,
#  1852,
#  902,
#  1084,
#  1280,
#  2867,
#  1578,
#  1589,
#  779,
#  600,
#  290,
#  655,
#  298,
#  752,
#  602,
#  142,
#  2966,
#  2835,
#  781,
#  964,
#  1369,
#  1363,
#  2312,
#  703,
#  1780,
#  619,
#  2442,
#  2855,
#  713,
#  2662,
#  2305,
#  1467,
#  1268,
#  1688,
#  928,
#  605,
#  1682,
#  170,
#  2055,
#  2603,
#  1117,
#  2882,
#  1144,
#  1883,
#  1597,
#  1440,
#  1878,
#  210,
#  2561,
#  2281,
#  2170,
#  2520,
#  1925,
#  910,
#  507,
#  2242,
#  931,
#  1403,
#  2424,
#  2939,
#  1535,
#  1172,
#  788,
#  1636,
#  480,
#  914,
#  1299,
#  2989,
#  1163,
#  685,
#  769,
#  2033,
#  1215,
#  214,
#  2324,
#  2409,
#  755,
#  2298,
#  810,
#  2649,
#  2169,
#  1225,
#  580,
#  2303,
#  924,
#  2756,
#  2456,
#  2286,
#  1613,
#  2293,
#  171,
#  1680,
#  1557,
#  1679,
#  113,
#  644,
#  1928,
#  2407,
#  1628,
#  50,
#  2668,
#  1814,
#  1533,
#  2038,
#  2888,
#  1244,
#  1027,
#  516,
#  510,
#  711,
#  1611,
#  2078,
#  581,
#  997,
#  2705,
#  2064,
#  1728,
#  196,
#  2059,
#  1631,
#  2069,
#  1603,
#  636,
#  633,
#  2626,
#  439,
#  1023,
#  1471,
#  1366,
#  786,
#  1560,
#  2898,
#  481,
#  2277,
#  1262,
#  103,
#  1799,
#  180,
#  945,
#  2632,
#  901,
#  848,
#  2540,
#  127,
#  2420,
#  1152,
#  2717,
#  1504,
#  2226,
#  2797,
#  739,
#  2710,
#  1935,
#  804,
#  1243,
#  2043,
#  523,
#  1744,
#  1996,
#  2689,
#  2672,
#  2534,
#  2438,
#  2354,
#  324,
#  1686,
#  2333,
#  918,
#  1234,
#  717,
#  1291,
#  454,
#  1829,
#  1828,
#  1093,
#  744,
#  2510,
#  617,
#  1969,
#  1423,
#  1796,
#  2443,
#  1876,
#  2742,
#  2831,
#  310,
#  562,
#  571,
#  227,
#  1860,
#  1872,
#  1946,
#  2693,
#  2746,
#  2751,
#  983,
#  253,
#  1914,
#  2653,
#  1645,
#  1057,
#  1397,
#  40,
#  696,
#  2493,
#  1287,
#  266,
#  2217,
#  1793,
#  2839,
#  960,
#  2720,
#  456,
#  2159,
#  2370,
#  1887,
#  1776,
#  2463,
#  1376,
#  1227,
#  1806,
#  1469,
#  1334,
#  564,
#  350,
#  1,
#  748,
#  1054,
#  754,
#  756,
#  257,
#  1267,
#  642,
#  2618,
#  2511,
#  828,
#  1347,
#  2830,
#  2673,
#  1487,
#  336,
#  1420,
#  466,
#  63,
#  818,
#  1134,
#  501,
#  2829,
#  2771,
#  2342,
#  369,
#  2925,
#  2664,
#  230,
#  2918,
#  1488,
#  201,
#  2644,
#  2785,
#  207,
#  2638,
#  1669,
#  1848,
#  2071,
#  1455,
#  2467,
#  2044,
#  1077,
#  1457,
#  2148,
#  1039,
#  27,
#  1809,
#  1409,
#  2469,
#  911,
#  2016,
#  1904,
#  487,
#  2883,
#  1315,
#  484,
#  2319,
#  2076,
#  1649,
#  1136,
#  2878,
#  1788,
#  502,
#  596,
#  202,
#  1211,
#  668,
#  1756,
#  2569,
#  1124,
#  2182,
#  2575,
#  1142,
#  2892,
#  1094,
#  1297,
#  37,
#  239,
#  1438,
#  2863,
#  1380,
#  1110,
#  811,
#  2157,
#  1193,
#  1429,
#  1898,
#  1863,
#  2642,
#  73,
#  1705,
#  2739,
#  1986,
#  1576,
#  2366,
#  2130,
#  1707,
#  2172,
#  935,
#  2557,
#  2733,
#  2681,
#  2256,
#  2081,
#  280,
#  1360,
#  1249,
#  1253,
#  1256,
#  2539,
#  1456,
#  922,
#  1733,
#  1886,
#  2711,
#  741,
#  1962,
#  566,
#  514,
#  1819,
#  1310,
#  1305,
#  270,
#  2365,
#  1006,
#  1949,
#  796,
#  1953,
#  1139,
#  2698,
#  2547,
#  345,
#  2391,
#  1514,
#  1980,
#  2175,
#  2519,
#  2560,
#  2791,
#  1162,
#  846,
#  477,
#  525,
#  2353,
#  1950,
#  1737,
#  414,
#  2514,
#  2613,
#  954,
#  803,
#  2706,
#  2351,
#  2541,
#  393,
#  889,
#  1177,
#  1509,
#  464,
#  2388,
#  1570,
#  1559,
#  2382,
#  2881,
#  2577,
#  2622,
#  2617,
#  1450,
#  1892,
#  330,
#  2592,
#  2542,
#  1632,
#  1975,
#  1795,
#  1868,
#  639,
#  1120,
#  7,
#  2952,
#  2508,
#  1204,
#  590,
#  584,
#  2408,
#  316,
#  2041,
#  1323,
#  1322,
#  1029,
#  681,
#  102,
#  2568,
#  1405,
#  1697,
#  1994,
#  570,
#  2615,
#  629,
#  941,
#  46,
#  1713,
#  802,
#  1719,
#  2224,
#  1492,
#  392,
#  8,
#  173,
#  2094,
#  1642,
#  1583,
#  2113,
#  2270,
#  738,
#  2728,
#  31,
#  1982,
#  762,
#  1179,
#  1264,
#  348,
#  450,
#  384,
#  687,
#  273,
#  1206,
#  827,
#  1070,
#  2721,
#  1417,
#  1717,
#  467,
#  1532,
#  1435,
#  2582,
#  900,
#  2752,
#  1694,
#  20,
#  339,
#  357,
#  387,
#  1416,
#  1716,
#  421,
#  2131,
#  2192,
#  2274,
#  506,
#  123,
#  2472,
#  2246,
#  1895,
#  870,
#  2048,
#  2193,
#  2245,
#  588,
#  950,
#  2313,
#  2915,
#  1536,
#  2413,
#  1053,
#  558,
#  845,
#  1565,
#  819,
#  927,
#  2150,
#  1910,
#  2556,
#  1002,
#  2621,
#  967,
#  2853,
#  354,
#  463,
#  1714,
#  686,
#  1638,
#  999,
#  1208,
#  2513,
#  982,
#  1028,
#  1619,
#  1963,
#  699,
#  2006,
#  988,
#  2348,
#  1377,
#  478,
#  1890,
#  138,
#  962,
#  830,
#  1735,
#  2221,
#  2368,
#  1571,
#  2630,
#  1666,
#  249,
#  2967,
#  1034,
#  991,
#  1960,
#  48,
#  2901,
#  666,
#  1302,
#  969,
#  17,
#  2273,
#  353,
#  431,
#  1475,
#  377,
#  2669,
#  2254,
#  1319,
#  365,
#  246,
#  2227,
#  2926,
#  2529,
#  2734,
#  1251,
#  1378,
#  863,
#  279,
#  1627,
#  867,
#  2500,
#  2119,
#  2120,
#  2206,
#  505,
#  607,
#  1257,
#  1699,
#  285,
#  2581,
#  2607,
#  2104,
#  2121,
#  2713,
#  2997,
#  793,
#  1055,
#  1477,
#  549,
#  2631,
#  13,
#  2028,
#  499,
#  ...]

# %% [markdown]
# # Define a function to clean the symptoms to categorize for easier wiki searching

# %%
def clean_symptoms_to_categorize(symptoms_to_categorize):
    symptoms_to_wiki_search_list = []
    for symptom in symptoms_to_categorize:
        symptom = symptom.replace('_', ' ')
        symptoms_to_wiki_search_list.append(symptom)
    return symptoms_to_wiki_search_list

# %% [markdown]
# # Clean the unique symptoms list to be used for wiki querying (symptoms_to_wiki_search_list)

# %%
symptoms_to_wiki_search_list = clean_symptoms_to_categorize(unique_food_df_symptoms_list)

# %%
with open('symptoms_to_wiki_search_list.pkl', 'wb') as picklefile:
        pickle.dump(symptoms_to_wiki_search_list, picklefile)

# %% [markdown]
# # Define functions to create a corpus of wiki symptom pages

# %%
'''
This function attempts to scrape the text from a wiki page based on a supplied term 
using a function in the wikipedia api. If the page cannot be sourced, it will pass 
the resulting DisambiguationError.
''' 
def attempt_to_create_wiki_page(search_term):
    wiki_page = None
    try:
        wiki_page = wiki.page(search_term)
    except wiki.exceptions.DisambiguationError as e:
        pass
    
    return wiki_page

# %%
'''
This function attempts to create a full corpus out of each of the scraped page text.
If the page cannot be sourced based on the provided search term, it will attempt to append
the text 'medical' onto the search term to see if that results in a page. If that does not 
work then the it will input placeholder text for that missing page so that all indices
of the resulting corpus list match the indices of the supplied symptoms list. That way,
I will be able to properly identify which corpus associates to which symptom.
This function also prints a list of tuples of the symptoms that did not have a sourced page
and their associated indices. Therefore, I could manually search for those pages and replace
the content within the corpus list at the correct index
'''

def create_wiki_symptom_corpus(symptoms_to_wiki_search_list):
    symptoms_wiki_corpus = []
    missing_symptoms_list = []
    for index, symptom in enumerate(symptoms_to_wiki_search_list):
        try:
            symptom_wiki_page = attempt_to_create_wiki_page(symptom)
            if symptom_wiki_page is None:
                symptom_wiki_page = attempt_to_create_wiki_page(symptom + ' (medical)')
                if symptom_wiki_page is None:
                    symptom_wiki_page = '{} unavailable_page'.format(symptom)
                    symptoms_wiki_corpus.append(symptom_wiki_page)
                    missing_symptoms_list.append((symptom, index))
                    continue
                
            symptom_wiki_page = symptom_wiki_page.content.splitlines()
            symptom_wiki_page = clean_page(symptom_wiki_page)
            symptoms_wiki_corpus.append(symptom_wiki_page)
        except:
            symptom_wiki_page = '{} unavailable_page'.format(symptom)
            symptoms_wiki_corpus.append(symptom_wiki_page)
            missing_symptoms_list.append((symptom, index))
            continue

    print(missing_symptoms_list)
    return symptoms_wiki_corpus

# %% [markdown]
# # Define a function to replace the wiki symptom pages that weren't originally searchable

# %%
'''Since there might be many missing pages that I had to manually source, this function attempts
to replace all of them at their associated indices. And if the page titles I manually sourced
still do not result in a page, this function prints those still missing pages so I can try 
again.
'''

def replace_missing_wiki(missing_symptom_redo_list, symptoms_to_wiki_search_list):
    still_missing_list = []
    for missing_symptom in missing_symptom_redo_list:
        try:
            wiki_symptom = wiki.page(missing_symptom[0])
            wiki_symptom = wiki_symptom.content.splitlines()
            wiki_symptom = clean_page(wiki_symptom)
            symptoms_to_wiki_search_list[missing_symptom[1]] = wiki_symptom
        except:
            wiki_symptom = 'Page_Unavailable'
            symptoms_to_wiki_search_list[missing_symptom[1]] = wiki_symptom
            still_missing_list.append(missing_symptom)
    print(still_missing_list)
    return symptoms_to_wiki_search_list

# %% [markdown]
# # Test the create wiki symptom corpus function on subset of 10 symptoms

# %%
symptoms_to_wiki_search_list
# Out:
# ['swelling face',
#  'rash',
#  'wheezing',
#  'cough',
#  'hospitalisation',
#  'dyspnoea',
#  'choking',
#  'completed suicide',
#  'stress symptoms',
#  'death',
#  'mitral valve incompetence',
#  'cerebrovascular accident',
#  'heart rate increased',
#  'dizziness',
#  'blood pressure increased',
#  'palpitations',
#  'paraesthesia',
#  'physical examination',
#  'orthostatic hypotension',
#  'chest pain',
#  'extrasystoles',
#  'ventricular extrasystoles',
#  'alopecia',
#  'arthralgia',
#  'dermatologic examination',
#  'hypersensitivity',
#  'headache',
#  'hypotrichosis',
#  'myocardial infarction',
#  'flushing',
#  'erythema',
#  'pain',
#  'tenderness',
#  'food poisoning',
#  'malaise',
#  'creutzfeldt',
#  'jakob disease',
#  'abdominal pain',
#  'vomiting',
#  'diarrhoea',
#  'epistaxis',
#  'dyspepsia',
#  'eye oedema',
#  'sneezing',
#  'throat tightness',
#  'vision blurred',
#  'sinus pain',
#  'emergency care examination',
#  'eye pruritus',
#  'eye irritation',
#  'burning sensation',
#  'nausea',
#  'abdominal pain upper',
#  'dry throat',
#  'throat irritation',
#  'skin bleeding',
#  'skin burning sensation',
#  'blister',
#  'burns second degree',
#  'rigors',
#  'paraesthesia oral',
#  'impaired driving ability',
#  'asthenia',
#  'lethargy',
#  'depressed mood',
#  'muscle injury',
#  'feeling abnormal',
#  'tachycardia',
#  'caustic injury',
#  'loose stools',
#  'flatulence',
#  'blood potassium decreased',
#  'fatigue',
#  'urticaria',
#  'stools watery',
#  'abnormal behaviour',
#  'blood calcium increased',
#  'hypercalcaemia',
#  'depressed level of consciousness',
#  'blood sodium decreased',
#  'aphasia',
#  'tremor',
#  'hyponatraemia',
#  'grand mal convulsion',
#  'eye redness',
#  'eye pain',
#  'screaming',
#  'eye swelling',
#  'anxiety',
#  'thinking abnormal',
#  'hyperhidrosis',
#  'bradycardia',
#  'anaphylactic shock',
#  'migraine',
#  'medication error',
#  'cholelithiasis obstructive',
#  'jaundice',
#  'aspartate aminotransferase increased',
#  'alanine aminotransferase increased',
#  'rash pustular',
#  'pruritus',
#  'swelling',
#  'adverse drug reaction',
#  'pancreatitis',
#  'mood altered',
#  'anger',
#  'myalgia',
#  'difficulty in walking',
#  'disorientation',
#  'rash macular',
#  'depression',
#  'rhabdomyolysis',
#  'compartment syndrome',
#  'muscle disorder',
#  'fasciotomy',
#  'wound debridement',
#  'myoglobin blood increased',
#  'blood creatine phosphokinase increased',
#  'feeling jittery',
#  'disturbance in attention',
#  'pollakiuria',
#  'paranoia',
#  'decreased appetite',
#  'insomnia',
#  'thirst',
#  'retching',
#  'weight decreased',
#  'convulsion',
#  'gamma',
#  'glutamyltransferase increased',
#  'hot flush',
#  'night sweats',
#  'uterine disorder',
#  'uterine dilation and curettage',
#  'gynaecological examination',
#  'cervix disorder',
#  'postmenopausal haemorrhage',
#  'ultrasound scan abnormal',
#  'mood swings',
#  'body temperature increased',
#  'panic attack',
#  'agoraphobia',
#  'dysphonia',
#  'parkinson',
#  's disease',
#  'hypoventilation',
#  'drug toxicity',
#  'pallor',
#  'respiratory arrest',
#  'general symptom',
#  'back pain',
#  'testicular pain',
#  'prostatic pain',
#  'impaired work ability',
#  'haematuria',
#  'culture urine positive',
#  'anorexia',
#  'culture positive',
#  'pyrexia',
#  'confusional state',
#  'electrocardiogram abnormal',
#  'pain in extremity',
#  'chest discomfort',
#  'visual disturbance',
#  'brain damage',
#  'arrhythmia',
#  'swollen tongue',
#  'listeriosis',
#  'syncope',
#  'mouth injury',
#  'dysphagia',
#  'haematochezia',
#  'hypertonic bladder',
#  'weight increased',
#  'muscular weakness',
#  'computerised tomogram abnormal',
#  'blood cholesterol increased',
#  'blood triglycerides increased',
#  'white blood cell count increased',
#  'ovarian cyst',
#  'diverticulitis',
#  'skin discolouration',
#  'vomiting projectile',
#  'eyes sunken',
#  'loss of consciousness',
#  'oesophageal ulcer',
#  'abdominal mass',
#  'hepatomegaly',
#  'intensive care',
#  'intracranial aneurysm',
#  'heart rate abnormal',
#  'cardiac failure congestive',
#  'cardiac fibrillation',
#  'oedema mucosal',
#  'sinus congestion',
#  'rhinitis',
#  'eye discharge',
#  'aortic aneurysm',
#  'monoplegia',
#  'eye inflammation',
#  'rectal haemorrhage',
#  'glaucoma',
#  'ophthalmological examination',
#  'intraocular pressure increased',
#  'diplopia',
#  'hepatic enzyme increased',
#  'angioneurotic oedema',
#  'lipids increased',
#  'oedema peripheral',
#  'hemiparesis',
#  'lacunar infarction',
#  'dysarthria',
#  'sweat gland disorder',
#  'dermatitis diaper',
#  'abdominal distension',
#  'blood pressure decreased',
#  'dyskinesia',
#  'arterial injury',
#  'pupil fixed',
#  'carotid artery dissection',
#  'autopsy',
#  'surgery',
#  'drooling',
#  'botulism',
#  'neurological examination',
#  'hypoaesthesia oral',
#  'trichorrhexis',
#  'hepatitis toxic',
#  'chemical injury',
#  'atrial fibrillation',
#  'nail bed tenderness',
#  'nail discolouration',
#  'blood heavy metal increased',
#  'infection',
#  'skin injury',
#  'cardioversion',
#  'drug screen positive',
#  'hair disorder',
#  'feeling hot',
#  'delirium',
#  'disability',
#  'serum sickness',
#  'cardiac disorder',
#  'blood creatine phosphokinase mb increased',
#  'gastroenteritis vibrio',
#  'metal poisoning',
#  'feeling of body temperature change',
#  'gastroenteritis salmonella',
#  'blood glucose increased',
#  'angina pectoris',
#  'haemoglobin decreased',
#  'gastrointestinal discomfort',
#  'diabetes mellitus',
#  'mania',
#  'panic disorder',
#  'anxiety disorder',
#  'ventricular tachycardia',
#  'dehydration',
#  'gastrointestinal disorder',
#  'blood culture positive',
#  'fibromyalgia',
#  'neck pain',
#  'pulmonary embolism',
#  'troponin increased',
#  'constipation',
#  'tinnitus',
#  'hypoglycaemia',
#  'sinus tachycardia',
#  'rash generalised',
#  'hypoaesthesia',
#  'colitis',
#  'carpal tunnel syndrome',
#  'walking aid user',
#  'abscess drainage',
#  'liver function test abnormal',
#  'chromaturia',
#  'jarisch',
#  'herxheimer reaction',
#  'lymphadenopathy',
#  'skin papilloma',
#  'rash papular',
#  'sleep disorder',
#  'hypersomnia',
#  'irritability',
#  'balance disorder',
#  'altered visual depth perception',
#  'hypertension',
#  'laparoscopic surgery',
#  'cholelithiasis',
#  'endoscopy abnormal',
#  'inflammation',
#  'duodenitis',
#  'irritable bowel syndrome',
#  'faeces pale',
#  'hepatic function abnormal',
#  'supraventricular tachycardia',
#  'liver transplant',
#  'hepatic necrosis',
#  'biopsy liver abnormal',
#  'dermatitis exfoliative',
#  'nervousness',
#  'gastrooesophageal reflux disease',
#  'wound',
#  'emotional distress',
#  'excoriation',
#  'haemorrhage',
#  'blood creatinine increased',
#  'blood oestrogen increased',
#  'breast pain',
#  'hypertensive crisis',
#  'influenza like illness',
#  'brain stem haemorrhage',
#  'abdominal discomfort',
#  'chemical burn of skin',
#  'hyperkalaemia',
#  'blood bilirubin increased',
#  'gastric ulcer',
#  'heart rate irregular',
#  'hyperventilation',
#  'faecaloma',
#  'gait abnormal',
#  'hair colour changes',
#  'intestinal haemorrhage',
#  'fat embolism',
#  'skin irritation',
#  'generalised erythema',
#  'acute myocardial infarction',
#  'thyroxine free increased',
#  'clostridial infection',
#  'coronary arterial stent insertion',
#  'coronary artery dissection',
#  'energy increased',
#  'anaphylactoid reaction',
#  'hepatitis',
#  'blood alkaline phosphatase increased',
#  'encephalopathy',
#  'hepatitis cholestatic',
#  'generalised oedema',
#  'growth retardation',
#  'failure to thrive',
#  'ill',
#  'defined disorder',
#  'haematemesis',
#  'pancytopenia',
#  'meningitis',
#  'change of bowel habit',
#  'congestive cardiomyopathy',
#  'agitation',
#  'oedema',
#  'renal insufficiency',
#  'eosinophilia myalgia syndrome',
#  'eosinophilia',
#  'eyelid disorder',
#  'skin disorder',
#  'discomfort',
#  'foreign body trauma',
#  'anaphylactic reaction',
#  'neuralgia',
#  'fall',
#  'ataxia',
#  'concussion',
#  'laceration',
#  'benign intracranial hypertension',
#  'papilloedema',
#  'endometrial cancer',
#  'endometrial cancer stage ii',
#  'menorrhagia',
#  'skin warm',
#  'asthma',
#  'pneumonia',
#  'skin desquamation',
#  'micturition disorder',
#  'faeces discoloured',
#  'gastritis',
#  'keratoconjunctivitis sicca',
#  'hepatitis acute',
#  'renal failure acute',
#  'pancreatitis acute',
#  'pulmonary congestion',
#  'conjunctivitis',
#  'restlessness',
#  'nasal congestion',
#  'enteritis',
#  'scar',
#  'diarrhoea haemorrhagic',
#  'transaminases increased',
#  'candidiasis',
#  'metabolic acidosis',
#  'myositis',
#  'pericarditis',
#  'somnolence',
#  'activities of daily living impaired',
#  'hyperthermia',
#  'ventricular dysfunction',
#  'tooth injury',
#  'vaginal mycosis',
#  'erectile dysfunction',
#  'cholera',
#  'skin reaction',
#  'skin tightness',
#  'stomach discomfort',
#  'lipase increased',
#  'hallucination',
#  'muscle tightness',
#  'scab',
#  'neurological symptom',
#  'gastric disorder',
#  'blood testosterone increased',
#  'brain abscess',
#  'abdominal abscess',
#  'respiratory rate increased',
#  'renal disorder',
#  'face injury',
#  'hypotension',
#  'heart rate decreased',
#  'blood potassium increased',
#  'multiple allergies',
#  'dry skin',
#  'face oedema',
#  'granuloma',
#  'urticaria generalised',
#  'international normalised ratio increased',
#  'intestinal obstruction',
#  'culture stool positive',
#  'cataract',
#  'bilirubin conjugated increased',
#  'cholestasis',
#  'biopsy liver',
#  'coronary artery disease',
#  'catheterisation cardiac',
#  'angioplasty',
#  'vulvovaginal discomfort',
#  'urinary tract infection',
#  'culture wound positive',
#  'electrocardiogram st segment elevation',
#  'hepatic failure',
#  'hepatic cirrhosis',
#  'pulse absent',
#  'coma',
#  'memory impairment',
#  'cerebral ischaemia',
#  'rhinorrhoea',
#  'urine output decreased',
#  'computerised tomogram',
#  'sympathectomy',
#  'pulmonary oedema',
#  'hyperthyroidism',
#  'glossodynia',
#  'lip pain',
#  'dysuria',
#  'cellulitis',
#  'lip dry',
#  'aortic dissection',
#  'oropharyngeal swelling',
#  'speech disorder',
#  'feeling cold',
#  'vaginal haemorrhage',
#  'foaming at mouth',
#  'mydriasis',
#  'intubation',
#  'hyperaesthesia',
#  'musculoskeletal stiffness',
#  'arthritis',
#  'skin lesion',
#  'prothrombin time prolonged',
#  'pharyngitis',
#  'shock',
#  'nephritis',
#  'dysgeusia',
#  'breast cancer',
#  'postnasal drip',
#  'ear disorder',
#  'hepatotoxicity',
#  'retinal detachment',
#  'visual acuity reduced',
#  'increased appetite',
#  'fungal infection',
#  'cyst',
#  'kidney infection',
#  'bone cancer metastatic',
#  'dysmenorrhoea',
#  'haematoma',
#  'whole blood transfusion',
#  'fracture',
#  'coeliac disease',
#  'crying',
#  'oral discomfort',
#  'gastrointestinal haemorrhage',
#  'ascites',
#  'pyuria',
#  'respiratory failure',
#  'coronary artery occlusion',
#  'psychotic disorder',
#  'delusion',
#  'suicidal ideation',
#  'pharyngeal oedema',
#  'gastrointestinal pain',
#  'cardiac murmur',
#  'pulmonary hypertension',
#  'dyspnoea exertional',
#  'tourette',
#  's disorder',
#  'pruritus generalised',
#  'ischaemic stroke',
#  'psychomotor hyperactivity',
#  'aortic rupture',
#  'lip discolouration',
#  'injection site necrosis',
#  'lip blister',
#  'anaemia',
#  'choking sensation',
#  'nephrolithiasis',
#  'respiratory disorder',
#  'joint swelling',
#  'acute myeloid leukaemia',
#  'systemic lupus erythematosus',
#  'micturition urgency',
#  'incontinence',
#  'oral mucosal blistering',
#  'vaginal polyp',
#  'genital rash',
#  'erythropenia',
#  'breast swelling',
#  'breast discharge',
#  'compression fracture',
#  'ischaemia',
#  'pain in jaw',
#  'cardiac pacemaker insertion',
#  'enterobacter infection',
#  'thrombocytopenic purpura',
#  'ovarian cancer',
#  'lung neoplasm malignant',
#  'argyria',
#  'osteopenia',
#  'keloid scar',
#  'overdose',
#  'iritis',
#  'chemotherapy',
#  'chemical eye injury',
#  'steroid therapy',
#  'blood pressure fluctuation',
#  'eructation',
#  'hypertrophy breast',
#  'hepatic encephalopathy',
#  'cyanosis',
#  'injury asphyxiation',
#  'vascular injury',
#  'bone densitometry',
#  'proteinuria',
#  'global amnesia',
#  'amnesia',
#  'metabolic alkalosis',
#  'apnoea',
#  'eczema',
#  'stool analysis abnormal',
#  'dry mouth',
#  'diabetic ketoacidosis',
#  'skin candida',
#  'anaphylaxis treatment',
#  'resuscitation',
#  'food allergy',
#  'thyrotoxicosis',
#  'hypothyroidism',
#  'polyuria',
#  'ulcer',
#  'conversion disorder',
#  'thyroid disorder',
#  'nervous system disorder',
#  'defaecation urgency',
#  'genital pruritus female',
#  'oral pruritus',
#  'bronchial oedema',
#  'macular degeneration',
#  'oesophageal obstruction',
#  'therapeutic agent toxicity',
#  'tachypnoea',
#  'sinusitis',
#  'rheumatoid arthritis',
#  'rebound effect',
#  'blindness',
#  'lip neoplasm malignant stage unspecified',
#  'radiotherapy',
#  'dysphasia',
#  'general physical health deterioration',
#  'concomitant disease progression',
#  'gynaecomastia',
#  'blood testosterone decreased',
#  'mitral valve stenosis',
#  'mitral valve replacement',
#  'faecal incontinence',
#  'corneal abrasion',
#  'septic shock',
#  'cerebral haemorrhage',
#  'nuclear magnetic resonance imaging brain abnormal',
#  'hoarseness',
#  'mental status changes',
#  'rhonchi',
#  'musculoskeletal disorder',
#  'tonic clonic movements',
#  'urinary retention',
#  'bladder catheter temporary',
#  'carcinoma',
#  'cardiac failure',
#  'atherosclerosis',
#  'muscle cramp',
#  'muscle twitching',
#  'neutropenia',
#  'thermal burn',
#  'tooth disorder',
#  'toothache',
#  'endodontic procedure',
#  'bacteraemia',
#  'nasopharyngitis',
#  'supraventricular extrasystoles',
#  'lacrimation increased',
#  'eye injury',
#  'hepatocellular damage',
#  'acne',
#  'colon injury',
#  'secretion discharge',
#  'guillain',
#  'barre syndrome',
#  'poisoning',
#  'mental impairment',
#  'urinary tract pain',
#  'electrocardiogram qt prolonged',
#  'thyroxine decreased',
#  'blood thyroid stimulating hormone decreased',
#  'petechiae',
#  'red cell distribution width increased',
#  'myeloproliferative disorder',
#  'meige',
#  's syndrome',
#  'hepatic neoplasm malignant',
#  'gastrointestinal stromal tumour',
#  'metastasis',
#  'hypertrichosis',
#  'head discomfort',
#  'cardiac arrest',
#  'blood calcium decreased',
#  'abasia',
#  'corneal scar',
#  'eye infection',
#  'coronary artery embolism',
#  'coronary artery surgery',
#  'bacterial infection',
#  'glossitis',
#  'chills',
#  'staphylococcal infection',
#  'seroma',
#  'dermatitis allergic',
#  'heat exhaustion',
#  'urinary incontinence',
#  'temperature intolerance',
#  'hypokalaemia',
#  'blood amylase increased',
#  'hirsutism',
#  'blood urine',
#  'adrenal insufficiency',
#  'dependence',
#  'flank pain',
#  'brain neoplasm',
#  'urinary hesitation',
#  'transient ischaemic attack',
#  'rash pruritic',
#  'blood creatine increased',
#  'vertigo',
#  'syncope vasovagal',
#  'atrial flutter',
#  'ventricular fibrillation',
#  'hypokinesia',
#  'arterial spasm',
#  'sudden death',
#  'troponin i increased',
#  'arteriospasm coronary',
#  'stridor',
#  'leukocytosis',
#  'mucosal inflammation',
#  'overwork',
#  'hyperphagia',
#  'salivary gland disorder',
#  'oral soft tissue disorder',
#  'eyelid oedema',
#  'hyperprolactinaemia',
#  'periorbital haematoma',
#  'exophthalmos',
#  'abortion spontaneous',
#  'metrorrhagia',
#  'herpes simplex',
#  'salivary hypersecretion',
#  'dysgraphia',
#  'onychomycosis',
#  'nail disorder',
#  'bone pain',
#  'vaginal infection',
#  'haemorrhagic diathesis',
#  'bone lesion',
#  'purpura',
#  'pain exacerbated',
#  'lactose intolerance',
#  'flat affect',
#  'uterine spasm',
#  'menstrual discomfort',
#  'brain oedema',
#  'carotid artery occlusion',
#  'arterial stenosis limb',
#  'gastroenteritis viral',
#  'circulatory collapse',
#  'malignant melanoma',
#  'skin test',
#  'feelings of worthlessness',
#  'piloerection',
#  'skin wrinkling',
#  'fluid retention',
#  'varices oesophageal',
#  'faecal occult blood positive',
#  'haematocrit decreased',
#  'accidental overdose',
#  'auditory',
#  'hyperacusis',
#  'urogenital disorder',
#  'hepatitis a',
#  'fear',
#  'delusional disorder',
#  'persecutory type',
#  'gastric outlet obstruction',
#  'hormone level abnormal',
#  'myopathy steroid',
#  'muscle fatigue',
#  'subdural haematoma',
#  'aggression',
#  'local swelling',
#  'tongue oedema',
#  'oedema mouth',
#  'international normalised ratio decreased',
#  'red blood cell count decreased',
#  'pco2 abnormal',
#  'localised oedema',
#  'pharyngolaryngeal pain',
#  'ear pain',
#  'skin inflammation',
#  'tongue disorder',
#  'tension',
#  'priapism',
#  'painful erection',
#  'bile duct obstruction due to calculus',
#  'hepatic atrophy',
#  'gingival disorder',
#  'gingival pain',
#  'gingival swelling',
#  'skin cancer',
#  'hyperplasia',
#  'dysplasia',
#  'lymphadenectomy',
#  'myeloid metaplasia',
#  'thyroid function test abnormal',
#  'coordination abnormal',
#  'non',
#  'cardiac chest pain',
#  'breast mass',
#  'migraine without aura',
#  'haemoptysis',
#  'haemoglobin increased',
#  'basophil count decreased',
#  'red blood cell count abnormal',
#  'eosinophil count abnormal',
#  'neutrophil count decreased',
#  'deafness',
#  'night blindness',
#  'fluid imbalance',
#  'thought blocking',
#  'skin exfoliation',
#  'blood blister',
#  'renal pain',
#  'ileus',
#  'ocular hyperaemia',
#  'photopsia',
#  'shigella infection',
#  'skin laceration',
#  'tunnel vision',
#  'formication',
#  'diabetic coma',
#  'body temperature decreased',
#  'bronchitis',
#  'reactive protein increased',
#  'neutrophil count increased',
#  'lymphocyte count increased',
#  'blood lactate dehydrogenase increased',
#  'serum ferritin increased',
#  'spleen scan abnormal',
#  'electrocardiogram change',
#  'deep vein thrombosis',
#  'thrombosis',
#  'reaction to food additive',
#  'skin chapped',
#  'blood glucose decreased',
#  'drug interaction',
#  'gait disturbance',
#  'hypoxia',
#  'blood urea increased',
#  'renal impairment',
#  'intentional self',
#  'injury',
#  'renal failure',
#  'vaginal erythema',
#  'sleep apnoea syndrome',
#  'steatorrhoea',
#  'squamous cell carcinoma',
#  'hyperkeratosis',
#  'myoclonus',
#  'blood albumin decreased',
#  'small intestine ulcer',
#  'skin depigmentation',
#  'keratitis',
#  'obstructive airways disorder',
#  'mental retardation severity unspecified',
#  'muscle spasms',
#  'chest wall pain',
#  'feeling hot and cold',
#  'abdominal hernia',
#  'vitamin d increased',
#  'sepsis',
#  'gastroenteritis',
#  'cardiovascular disorder',
#  'cardio',
#  'respiratory distress',
#  'bladder pain',
#  'oral pain',
#  'hair texture abnormal',
#  'hair growth abnormal',
#  'escherichia infection',
#  'coagulation test abnormal',
#  'ammonia increased',
#  'skin swelling',
#  'hereditary cerebral degeneration',
#  'listless',
#  'oesophageal injury',
#  'cardiac enzymes increased',
#  'splinter',
#  'chapped lips',
#  'ecchymosis',
#  'activated partial thromboplastin time prolonged',
#  'loss of libido',
#  'decreased immune responsiveness',
#  'lower respiratory tract infection',
#  'polyneuropathy',
#  'hypometabolism',
#  'blood glucose abnormal',
#  'abdominal infection',
#  'apallic syndrome',
#  'pancreatic enzymes increased',
#  'laboratory test abnormal',
#  'intestinal functional disorder',
#  'paraneoplastic syndrome',
#  'prostatic specific antigen increased',
#  'contusion',
#  'tongue biting',
#  'acarodermatitis',
#  'ocular icterus',
#  'creatinine renal clearance decreased',
#  'gallbladder disorder',
#  'glomerular filtration rate decreased',
#  'blood caffeine increased',
#  'blood sodium increased',
#  'blood electrolytes decreased',
#  'cold sweat',
#  'bedridden',
#  'gastroenteritis escherichia coli',
#  'dermatitis',
#  'eyelash thickening',
#  'thyroxine free decreased',
#  'high density lipoprotein increased',
#  'low density lipoprotein increased',
#  'blood urine present',
#  'incoherent',
#  'hunger',
#  'sleep walking',
#  'dry eye',
#  'torsade de pointes',
#  'lipids abnormal',
#  'abnormal faeces',
#  'blood bicarbonate decreased',
#  'blood cholesterol decreased',
#  'blood fibrinogen increased',
#  'high density lipoprotein decreased',
#  'low density lipoprotein decreased',
#  'blood magnesium increased',
#  'pco2 decreased',
#  'platelet count decreased',
#  'protein total decreased',
#  'brain stem syndrome',
#  'analgesic effect',
#  'salmonellosis',
#  'poverty of thought content',
#  'myoglobinuria',
#  'disturbance in sexual arousal',
#  'organ failure',
#  'platelet count increased',
#  'posturing',
#  'cardiomyopathy',
#  'ejection fraction decreased',
#  'pulse pressure decreased',
#  'ventricular arrhythmia',
#  'increased bronchial secretion',
#  'respiratory tract congestion',
#  'eye haemorrhage',
#  'carbon dioxide abnormal',
#  'diabetes mellitus non',
#  'insulin',
#  'dependent',
#  'dystonia',
#  'peripheral coldness',
#  'nasal dryness',
#  'skin infection',
#  'enuresis',
#  'status epilepticus',
#  'electroencephalogram abnormal',
#  'urine ketone body present',
#  'blood chloride increased',
#  'blood urea decreased',
#  'loss of visual contrast sensitivity',
#  'cognitive disorder',
#  'klebsiella infection',
#  'enterococcal infection',
#  'gastroenteritis proteus',
#  'serratia infection',
#  'endocarditis enterococcal',
#  'escherichia bacteraemia',
#  'jaw fracture',
#  'nonspecific reaction',
#  'colonoscopy',
#  'oesophagogastroduodenoscopy',
#  'endoscopy',
#  'ray with contrast upper gastrointestinal tract',
#  'hepatic pain',
#  'body temperature fluctuation',
#  'myocarditis',
#  'angiogram',
#  'electrocardiogram st segment',
#  'dermatitis bullous',
#  'lymphatic disorder',
#  'polydipsia',
#  'red blood cell sedimentation rate abnormal',
#  'intercostal retraction',
#  'stomatitis',
#  'lentigo',
#  'bacillus infection',
#  'vulvovaginal dryness',
#  'excitability',
#  'endoscopy upper gastrointestinal tract',
#  'nodal rhythm',
#  'acute coronary syndrome',
#  'vasculitis',
#  'chronic obstructive pulmonary disease',
#  'haemodynamic instability',
#  'electrolyte imbalance',
#  'abdominal tenderness',
#  'protein total abnormal',
#  'blood chloride decreased',
#  'blood phosphorus increased',
#  'hypervitaminosis',
#  'blood creatinine decreased',
#  'tachyarrhythmia',
#  'pressure of speech',
#  'haemorrhoids',
#  'blood cortisol increased',
#  'autonomic nervous system imbalance',
#  'poor peripheral circulation',
#  'vertigo positional',
#  'sinus headache',
#  'tongue dry',
#  'gingival infection',
#  'hepatic steatosis',
#  'disease progression',
#  'bile duct obstruction',
#  'joint stiffness',
#  'disseminated intravascular coagulation',
#  'sensation of foreign body',
#  'parathyroid disorder',
#  'parathyroid gland enlargement',
#  'pneumonia aspiration',
#  'brain stem infarction',
#  'central nervous system function test abnormal',
#  'glasgow coma scale abnormal',
#  'liver disorder',
#  'bile output increased',
#  'sleep terror',
#  'spinal fracture',
#  'panic reaction',
#  'parathyroidectomy',
#  'thyroid neoplasm',
#  'wound secretion',
#  'dandruff',
#  'eye infection viral',
#  'hypervitaminosis d',
#  'calcium intoxication',
#  'stool analysis',
#  'abdominal pain lower',
#  'optic neuritis',
#  'brain mass',
#  ...]

# %%
# Seems like it fails to scrape pages for about half of the symptoms
test_10_wiki_corpus = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[0:11])
# Out:
# []

# %%
test_10_wiki_corpus
# Out:
olapse mvp and is the most common cause of primary mitral regurgitation in the united states causing about  of cases myxomatous degeneration of the mitral valve is more common in women as well as with advancing age which causes a stretching of the leaflets of the valve and the chordae tendineae such elongation prevents the valve leaflets from fully coming together when the valve closes causing the valve leaflets to prolapse into the left atrium thereby causing miischemic heart disease causes mi by the combination of ischemic dysfunction of the papillary muscles and the dilatation of the left ventricle this can lead to the subsequent displacement of the papillary muscles and the dilatation of the mitral valve annulusrheumatic fever rf and marfans syndrome are other typical causes mitral valve stenosis mvs can sometimes be a cause of mitral regurgitation mr in the sense that a stenotic valve calcified and with restricted range of movement allows backflow regurgitation if it is too stiff and misshapen to close completely most m ...

# %% [markdown]
# # Scrape subsets of the 3k symptoms at a time

# %% [markdown]
# # First 200

# %%
full_corpus_200 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[0:200])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# loose stools unavailable_page
# Failed at: loose stools, at index 69
# stools watery unavailable_page
# Failed at: stools watery, at index 74
# mood altered unavailable_page
# Failed at: mood altered, at index 104
# disturbance in attention unavailable_page
# Failed at: disturbance in attention, at index 119
# chest discomfort unavailable_page
# Failed at: chest discomfort, at index 162
# hypertonic bladder unavailable_page
# Failed at: hypertonic bladder, at index 172
# computerised tomogram abnormal unavailable_page
# Failed at: computerised tomogram abnormal, at index 175
# sinus congestion unavailable_page
# Failed at: sinus congestion, at index 194
# [('loose stools', 69), ('stools watery', 74), ('mood altered', 104), ('disturbance in attention', 119), ('chest discomfort', 162), ('hypertonic bladder', 172), ('computerised tomogram abnormal', 175), ('sinus congestion', 194)]

# %%
replacement_200 = [('Diarrhea', 69), ('Diarrhea', 74), ('Mood swing', 104), ('Attention span', 119), ('Acute bronchitis', 162), ('Overactive bladder', 172), ('CT scan', 175), ('Nasal congestion', 194)]

# %%
full_corpus_200_fixed = replace_missing_wiki(replacement_200, full_corpus_200)
# Out:
# []

# %%
with open('full_corpus_200_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_200_fixed, picklefile)

# %% [markdown]
# # Next 200 (400)

# %%
full_corpus_400 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[200:400])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('pupil fixed', 18), ('chromaturia', 75), ('faeces pale', 93), ('hair colour changes', 121), ('coronary arterial stent insertion', 129), ('change of bowel habit', 145), ('skin warm', 167), ('faeces discoloured', 172), ('transaminases increased', 185)]

# %%
replacement_400 = [('Mydriasis', 18), ('Urine', 75), ('Common bile duct stone', 93), ('Human hair color', 121), ('Coronary catheterization', 129), ('Rectal discharge', 145), ('Desquamation', 167), ('Human feces', 172), ('Elevated transaminases', 185)]

# %%
full_corpus_400_fixed = replace_missing_wiki(replacement_400, full_corpus_400)
# Out:
# []

# %%
with open('/Corpus/full_corpus_400_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_400_fixed, picklefile)

# %% [markdown]
# # Next 200 (600)

# %%
full_corpus_600 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[400:600])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('scab', 4), ('international normalised ratio increased', 21), ('catheterisation cardiac', 29), ('culture wound positive', 33), ('computerised tomogram', 43), ('shock', 66), ('bone cancer metastatic', 79), ('dyspnoea exertional', 99), ('pruritus generalised', 102), ('lip blister', 108), ('vaginal polyp', 119), ('genital rash', 120), ('apnoea', 152), ('defaecation urgency', 168), ('genital pruritus female', 169), ('lip neoplasm malignant stage unspecified', 180), ('tonic clonic movements', 198)]

# %%
replacement_600 = [('Fibroblast', 4), ('Prothrombin time', 21), ('Cardiac catheterization', 29), ('Open fracture', 33), ('CT scan', 43), ('Shock (circulatory)', 66), ('Metastatic breast cancer', 79), ('Shortness of breath', 99), ('Itch', 102), ('Blister', 108), ('Endometrial polyp', 119), ('Genital herpes', 120), ('Apnea', 152), ('Diarrhea', 168), ('Vulva', 169), ('Oral cancer', 180), ('Clonus', 198)]

# %%
full_corpus_600_fixed = replace_missing_wiki(replacement_600, full_corpus_600)
# Out:
# []

# %%
with open('/Corpus/full_corpus_600_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_600_fixed, picklefile)

# %% [markdown]
# # Next 200 (800)

# %%
full_corpus_800 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[600:800])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('meige', 31), ('hepatic neoplasm malignant', 33), ('corneal scar', 41), ('arteriospasm coronary', 74), ('uterine spasm', 101), ('brain oedema', 103), ('arterial stenosis limb', 105), ('oedema mouth', 133), ('international normalised ratio decreased', 134), ('pco2 abnormal', 136), ('basophil count decreased', 163), ('eosinophil count abnormal', 165), ('body temperature decreased', 182), ('skin chapped', 194)]

# %%
replacement_800 = [('Meige lymphedema', 31), ('Liver cancer', 33), ('Corneal ulcer', 41), ('Coronary vasospasm', 74), ('Braxton Hicks contractions', 101), ('Cerebral edema', 103), ('Carotid artery stenosis', 105), ('Angioedema', 133), ('Prothrombin time', 134), ('pCO2', 136), ('White blood cell', 163), ('Eosinophilia', 165), ('Thermoregulation', 182), ('Xeroderma', 194)]

# %%
full_corpus_800_fixed = replace_missing_wiki(replacement_800, full_corpus_800)
# Out:
# []

# %%
with open('/Corpus/full_corpus_800_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_800_fixed, picklefile)

# %% [markdown]
# # Next 200 (1000)

# %%
full_corpus_1000 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[800:1000])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('mental retardation severity unspecified', 15), ('prostatic specific antigen increased', 54), ('creatinine renal clearance decreased', 59), ('blood electrolytes decreased', 64), ('abnormal faeces', 80), ('pco2 decreased', 87), ('poverty of thought content', 93), ('increased bronchial secretion', 103), ('respiratory tract congestion', 104), ('peripheral coldness', 111), ('nasal dryness', 112), ('gastroenteritis proteus', 124), ('dermatitis bullous', 139), ('intercostal retraction', 143), ('vulvovaginal dryness', 147), ('bile output increased', 185)]

# %%
replacement_1000 = [('Intellectual disability', 15), ('Prostate-specific antigen', 54), ('Renal function', 59), ('Hypovolemia', 64), ('Human feces', 80), ('pCO2', 87), ('Thought disorder', 93), ('Bronchial challenge test', 103), ('Upper respiratory tract infection', 104), ('Frostbite', 111), ('Dried nasal mucus', 112), ('Aeromonas hydrophila', 124), ('Dermatitis herpetiformis', 139), ('Labored breathing', 143), ('Vulvovaginal health', 147), ('Dehydrocholic acid', 185)]

# %%
full_corpus_1000_fixed = replace_missing_wiki(replacement_1000, full_corpus_1000)
# Out:
# []

# %%
with open('/Corpus/full_corpus_1000_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_1000_fixed, picklefile)

# %% [markdown]
# # Next 500 (1500)

# %%
full_corpus_1500 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[1000:1500])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('prothrombin level increased', 13), ('saliva altered', 18), ('frequent bowel movements', 48), ('limb injury', 57), ('blood creatine decreased', 71), ('caecal lesion excision', 75), ('metastases to kidney', 95), ('resistant staphylococcal aureus test positive', 99), ('urine arsenic increased', 105), ('elevated pacing threshold', 123), ('genital burning sensation', 128), ('operative haemorrhage', 141), ('retinal injury', 143), ('aspiration', 145), ('cardiac flutter', 154), ('respiration abnormal', 165), ('intentional drug misuse', 166), ('rash maculo', 169), ('papular', 170), ('increased upper airway secretion', 201), ('prealbumin decreased', 217), ('unevaluable event', 239), ('oedema genital', 240), ('onychalgia', 257), ('nasal oedema', 261), ('arthropod bite', 287), ('incorrect dose administered', 297), ('bile culture positive', 325), ('social avoidant behaviour', 332), ('cardiac discomfort', 341), ('bronchial irritation', 347), ('rash erythematous', 349), ('psychological factor affecting medical condition', 352), ('increased insulin requirement', 357), ('coma acidotic', 372), ('euphoric mood', 382), ('psychomotor skills impaired', 385), ('sensation of heaviness', 398), ('intentional overdose', 404), ('bile output abnormal', 412), ('genital haemorrhage', 416), ('induration', 432), ('pitting oedema', 439), ('painful defaecation', 444), ('mucous stools', 450)]

# %%
replacement_1500 = [('Prothrombin time', 13), ('Saliva testing', 18), ('Diarrhea', 48), ('Repetitive strain injury', 57), ('Creatine transporter defect', 71), ('Horse colic', 75), ('Renal cell carcinoma', 95), ('Methicillin-resistant Staphylococcus aureus', 99), ('Arsenic poisoning', 105), ('Pacemaker syndrome', 123), ('Genital herpes', 128), ('Bleeding', 141), ('Retinal detachment', 143), ('Aspiration pneumonia', 145), ('Atrial flutter', 154), ('Agonal respiration', 165), ('Substance abuse', 166), ('Maculopapular rash', 169), ('Maculopapular rash', 170), ('Upper respiratory tract infection', 201), ('Transthyretin', 217), ('unevaluable event', 239), ('Genital herpes', 240), ('Ingrown nail', 257), ('Nasal congestion', 261), ('Arthropod bites and stings', 287), ('Drug overdose', 297), ('Bile', 325), ('Anti-social behaviour', 332), ('Angina', 341), ('Acute bronchitis', 347), ('Erythema', 349), ('DSM-IV codes', 352), ('Insulin (medication)', 357), ('Acidosis', 372), ('Euphoria', 382), ('Topiramate', 385), ('Heavy legs', 398), ('drug overdose', 404), ('Secretin-cholecystokinin test', 412), ('Genital herpes', 416), ('Cutaneous condition', 432), ('Edema', 439), ('Rectal tenesmus', 444), ('Diarrhea', 450)]

# %% [markdown]
# ## Notice that there is one "symptom" that is basically 'unknown'

# %%
'''
Since this "symptom" is basically an unknown, 
I'm going to leave it as "Page_Unavailable" and take note of its index
'''
full_corpus_1500_fixed = replace_missing_wiki(replacement_1500, full_corpus_1500)
# Out:
# [('unevaluable event', 239)]

# %%
with open('/Corpus/full_corpus_1500_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_1500_fixed, picklefile)

# %% [markdown]
# # Next 500 (2000)

# %%
full_corpus_2000 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[1500:2000])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('anaesthetic complication', 12), ('ear tube insertion', 16), ('related event', 32), ('nasal inflammation', 35), ('respiratory tract irritation', 39), ('cross sensitivity reaction', 45), ('cardiac infection', 56), ('tachyphrenia', 58), ('colitis ischaemic', 61), ('feeling of relaxation', 71), ('nasal discomfort', 74), ('pulmonary vascular disorder', 82), ('atrial conduction time prolongation', 88), ('mouth ulceration', 92), ('therapeutic product ineffective', 97), ('post procedural haemorrhage', 136), ('faeces hard', 142), ('faecal volume increased', 143), ('blood gonadotrophin increased', 167), ('large intestinal haemorrhage', 168), ('clamping of blood vessel', 215), ('toxicologic test abnormal', 221), ('skin induration', 222), ('pco2 increased', 229), ('oropharyngeal spasm', 234), ('not coded', 242), ('early satiety', 247), ('cardioactive drug level increased', 255), ('post', 269), ('wound haemorrhage', 271), ('ear congestion', 278), ('beta haemolytic streptococcal infection', 300), ('congenital hyperextension of spine', 320), ('small intestinal resection', 338), ('intestinal infarction', 340), ('haemorrhagic infarction', 350), ('urine flow decreased', 357), ('full blood count decreased', 359), ('drug level increased', 363), ('spinal disorder', 368), ('diaphragmalgia', 371), ('disbacteriosis', 373), ('anastomotic ulcer', 418), ('gun shot wound', 444), ('depression suicidal', 446), ('complication of device removal', 474), ('immunoglobulins increased', 476), ('urine copper increased', 477), ('nasal disorder', 488), ('therapy regimen changed', 497)]

# %%
replacement_2000 = [('Complications of anesthetic gases', 12), ('Tympanostomy tube', 16), ('related event', 32), ('Nasal polyp', 35), ('Upper respiratory tract infection', 39), ('Sensitivity analysis', 45), ('Cardiac tamponade', 56), ('Euphoria', 58), ('Ischemic colitis', 61), ('relaxation technique', 71), ('Nasal congestion', 74), ('Vascular disease', 82), ('Heart arrhythmia', 88), ('Mouth ulcer', 92), ('therapeutic product ineffective', 97), ('Hemorrhagic cystitis', 136), ('Human feces', 142), ('Fecal impaction', 143), ('Gonadotropin', 167), ('Gastrointestinal bleeding', 168), ('Hemostat', 215), ('Adverse drug reaction', 221), ('Cutaneous condition', 222), ('pco2', 229), ('Cricopharyngeal spasm', 234), ('not coded', 242), ('Expected satiety', 247), ('Pharmacokinetics', 255), ('post', 269), ('Bleeding', 271), ('Nasal congestion', 278), ('Streptococcus', 300), ('Torticollis', 320), ('Small intestinal bacterial overgrowth', 338), ('Bowel infarction', 340), ('Thrombolysis', 350), ('Urinary retention', 357), ('Hypovolemia', 359), ('Drug overdose', 363), ('Spinal cord injury', 368), ('Diaphragmatic rupture', 371), ('Dysbiosis', 373), ('Gastric bypass surgery', 418), ('Gunshot wound', 444), ('Suicidal ideation', 446), ('ICD-10 Procedure Coding System', 474), ('Hyper IgM syndrome', 476), ('Copper in health', 477), ('Nasal septum deviation', 488), ('Pharmacotherapy', 497)]

# %%
full_corpus_2000_fixed = replace_missing_wiki(replacement_2000, full_corpus_2000)
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('related event', 32), ('therapeutic product ineffective', 97), ('not coded', 242), ('post', 269)]

# %% [markdown]
# ## Notice that there are a few 'symptoms' that I'm keeping as unavailable, as they aren't actually symptoms or I can't classify them yet.

# %%
with open('/Corpus/full_corpus_2000_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_2000_fixed, picklefile)

# %% [markdown]
# # Next 500 (2500)

# %%
full_corpus_2500 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[2000:2500])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('bile duct stent insertion', 8), ('performance status decreased', 25), ('bloody discharge', 37), ('basophil percentage increased', 51), ('accidental exposure', 53), ('retinal exudates', 61), ('creatine urine decreased', 63), ('cryptogenic cirrhosis', 78), ('buccal mucosal roughening', 84), ('ceruloplasmin decreased', 89), ('cholelithotomy', 91), ('albumin globulin ratio decreased', 105), ('globulins increased', 106), ('accidental drug intake by child', 108), ('failure of child resistant mechanism for pharmaceutical product', 109), ('oesophageal hypomotility', 121), ('urine arsenic', 162), ('throat lesion', 182), ('eye operation', 185), ('neutrophil percentage increased', 201), ('barrett', 209), ('contracted bladder', 211), ('oesophagogastric fundoplasty', 217), ('gastrointestinal sounds abnormal', 227), ('amniorrhoea', 232), ('reproductive tract disorder', 288), ('epiglottis ulcer', 292), ('pharyngeal hypoaesthesia', 308), ('urine amino acid level increased', 318), ('venous occlusion', 356), ('bladder irritation', 359), ('band neutrophil percentage increased', 384), ('rales', 387), ('dementia alzheimer', 390), ('urobilinogen faeces increased', 418), ('wound drainage', 451), ('hdl ratio decreased', 467), ('scrotal irritation', 470), ('trypsin decreased', 486), ('eyelid boil', 490), ('pupils unequal', 492)]

# %%
replacement_2500 = [('Endoscopic stenting', 8), ('Performance status', 25), ('Bleeding', 37), ('Basophil activation', 51), ('Blood agent', 53), ('Hypertensive retinopathy', 61), ('Creatine transporter defect', 63), ('Kayser–Fleischer ring', 78), ('Heck\'s disease', 84), ('Wilson\s disease', 89), ('lithotomy', 91), ('Sex hormone-binding globulin', 105), ('globulins increased', 106), ('Drug overdose', 108), ('Drug overdose', 109), ('Achalasia', 121), ('Arsenic poisoning', 162), ('Herpes labialis', 182), ('Eye surgery', 185), ('Absolute neutrophil count', 201), ('Barrett\'s esophagus', 209), ('Urinary incontinence', 211), ('Nissen fundoplication', 217), ('Stomach rumble', 227), ('Amenorrhea', 232), ('Reproductive system disease', 288), ('Human digestive system', 292), ('Hypoesthesia', 308), ('Congenital disorders of amino acid metabolism', 318), ('Central venous catheter', 356), ('Overactive bladder', 359), ('Absolute neutrophil count', 384), ('Crackles', 387), ('Alzheimer\'s disease', 390), ('Urine test strip', 418), ('Wound healing', 451), ('Cholesterol', 467), ('Scrotal ultrasound', 470), ('Serine protease', 486), ('Stye', 490), ('Anisocoria', 492)]

# %%
# I forgot to add Globulins increased before moving on 
full_corpus_2500_fixed = replace_missing_wiki(replacement_2500, full_corpus_2500)
# Out:
# [('globulins increased', 106)]

# %%
with open('/Corpus/full_corpus_2500_fixed.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_2500_fixed, picklefile)

# %% [markdown]
# # Next 500 (3000)

# %%
full_corpus_3000 = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[2500:3000])
# Out:
# /home/victoria/anaconda3/envs/ds/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/victoria/anaconda3/envs/ds/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [('uraemia odour', 5), ('vocal cord disorder', 10), ('monocyte count decreased', 13), ('myolipoma', 57), ('crohn', 64), ('oesophageal irritation', 74), ('blood corticotrophin increased', 99), ('hla marker study positive', 109), ('hepatic congestion', 119), ('upper respiratory tract irritation', 121), ('gastrointestinal tract irritation', 123), ('anoxia', 132), ('thyroxin binding globulin increased', 139), ('urine iron increased', 157), ('pneumonia lipoid', 169), ('biopsy bronchus abnormal', 170), ('short', 176), ('injurious ideation', 195), ('eczema weeping', 212), ('medical device complication', 216), ('foetal exposure timing unspecified', 225), ('genital disorder male', 236), ('blood electrolytes normal', 240), ('positron emission tomogram abnormal', 253), ('lung carcinoma cell type unspecified stage iv', 254), ('maternal exposure during pregnancy', 257), ('hyperproteinaemia', 270), ('device pacing issue', 271), ('medical induction of coma', 275), ('amino acid level increased', 276), ('retinal oedema', 279), ('faeces soft', 285), ('multiple fractures', 312), ('pancreatolithiasis', 339), ('seizure like phenomena', 343), ('eye contusion', 377), ('genital hypoaesthesia', 380), ('parasite tissue specimen test positive', 391), ('spinal x', 394), ('alopecia scarring', 397), ('postoperative thoracic procedure complication', 403), ('colonic abscess', 405), ('computerised tomogram thorax abnormal', 409), ('anaemia megaloblastic', 411), ('foetal growth restriction', 425), ('halo vision', 431), ('increased tendency to bruise', 443), ('micturition frequency decreased', 451), ('nephropathy toxic', 453), ('echoencephalogram abnormal', 459), ('eyelid exfoliation', 461), ('gastric mucosal lesion', 463), ('small fibre neuropathy', 467), ('device connection issue', 488), ('exposure via ingestion', 493), ('hypercarotinaemia', 496)]

# %%
replacement_3000 = [('Uremic fetor', 5), ('Vocal fold paresis', 10), ('Leukocytosis', 13), ('Blood vessel', 57), ('Crohn\'s disease', 64), ('Esophageal dysphagia', 74), ('blood corticotrophin increased', 99), ('hla marker study positive', 109), ('hepatic congestion', 119), ('upper respiratory tract irritation', 121), ('Desmopressin', 123), ('Hypoxia (medical)', 132), ('Thyroid hormones', 139), ('Urine test strip', 157), ('Lipid pneumonia', 169), ('Squamous cell carcinoma', 170), ('SHORT syndrome', 176), ('Suicide terminology', 195), ('Dermatitis', 212), ('Medical device', 216), ('Fetal alcohol spectrum disorder', 225), ('Male genital disease', 236), ('Blood', 240), ('PET-CT', 253), ('Lung cancer', 254), ('Drugs in pregnancy', 257), ('hyperproteinemia', 270), ('Artificial cardiac pacemaker', 271), ('Sodium thiopental', 275), ('Branched-chain amino acid', 276), ('Macular edema', 279), ('Human feces', 285), ('Bone fracture', 312), ('Exocrine pancreatic insufficiency', 339), ('Epileptic seizure', 343), ('Black eye', 377), ('Peripheral neuropathy', 380), ('Entamoeba histolytica', 391), ('Radiography', 394), ('Scarring hair loss', 397), ('Thoracotomy', 403), ('Pyogenic liver abscess', 405), ('CT scan', 409), ('Megaloblastic anemia', 411), ('Fetal viability', 425), ('Blurred vision', 431), ('Bruise', 443), ('Urination', 451), ('Nephrotoxicity', 453), ('Medical ultrasound', 459), ('Exfoliation (cosmetology)', 461), ('Gastric erosion', 463), ('Small fiber peripheral neuropathy', 467), ('Medical device connectivity', 488), ('Antigen', 493), ('Carotenosis', 496)]

# %%
full_corpus_3000_fixed = replace_missing_wiki(replacement_3000, full_corpus_3000)
# Out:
# [('blood corticotrophin increased', 99), ('hla marker study positive', 109), ('hepatic congestion', 119), ('upper respiratory tract irritation', 121)]

# %%
replacement_3000_redo = [('Desmopressin', 99), ('Human leukocyte antigen', 109), ('Congestive hepatopathy', 119), ('Upper respiratory tract infection', 121)]

# %%
full_corpus_3000_fixed_again = replace_missing_wiki(replacement_3000_redo, full_corpus_3000_fixed)
# Out:
# []

# %%
with open('/Corpus/full_corpus_3000_fixed_again.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_3000_fixed_again, picklefile)

# %% [markdown]
# # Obtain remainder of corpus (3004)

# %%
len(symptoms_to_wiki_search_list)
# Out:
# 3004

# %%
full_corpus_remainder = create_wiki_symptom_corpus(symptoms_to_wiki_search_list[3000:3050])
# Out:
# []

# %%
len(full_corpus_remainder)
# Out:
# 4

# %%
with open('/Corpus/full_corpus_remainder.pkl', 'wb') as picklefile:
        pickle.dump(full_corpus_remainder, picklefile)

# %% [markdown]
# # Summary

# %% [markdown]
# ### What I did
# 1. Scraped Wikipedia symptom page text
#
# ### What I will do next
# 1. Compile all subsets of the corpus that was scraped here into a full Wikipedia symptoms corpus
# 2. Vectorize the full corpus
# 3. Apply a KNN model to reduce the number of symptoms that will become the features in my final model
